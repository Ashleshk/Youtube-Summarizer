# %%
# !pip install youtube_transcript_api
# Out:
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /Users/ashleshkhajbage/Library/r-miniconda-arm64/lib/python3.10/site-packages (from youtube_transcript_api) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ashleshkhajbage/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests->youtube_transcript_api) (2024.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ashleshkhajbage/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests->youtube_transcript_api) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ashleshkhajbage/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests->youtube_transcript_api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ashleshkhajbage/Library/r-miniconda-arm64/lib/python3.10/site-packages (from requests->youtube_transcript_api) (3.4)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-0.6.2

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
from IPython.display import YouTubeVideo

# %%
video=input("Enter the link of your YouTube Video: ")

# %%
id_video=video.split("=")[1]
print(id_video)
# Out:
# T-JVpKku5SI

# %%
YouTubeVideo(id_video)

# %%
transcript = YouTubeTranscriptApi.get_transcript(id_video)

# %%
transcript
# Out:
# [{'text': 'Malcolm X once said that\n“Education is the passport to the future.”',
#   'start': 0.099,
#   'duration': 3.62},
#  {'text': 'But what if some passports\nare better than others,',
#   'start': 3.719,
#   'duration': 2.481},
#  {'text': 'giving the holder access\nto better schools and teachers',
#   'start': 6.2,
#   'duration': 2.39},
#  {'text': 'and, in turn,\na more prosperous future?',
#   'start': 8.59,
#   'duration': 2.69},
#  {'text': 'These inequalities have been around\nlong before Covid-19,',
#   'start': 11.28,
#   'duration': 2.32},
#  {'text': 'and yet, the pandemic has both exacerbated them\nand made them more visible.',
#   'start': 13.6,
#   'duration': 4.48},
#  {'text': 'While the standard of education\nvaries greatly globally,',
#   'start': 22.5,
#   'duration': 3.04},
#  {'text': 'education inequality happens\nat the local level in all countries.',
#   'start': 25.54,
#   'duration': 3.94},
#  {'text': 'For example, only four\nout of every 100 children in Africa',
#   'start': 29.48,
#   'duration': 3.48},
#  {'text': 'is expected to enter a graduate\nand postgraduate institution,',
#   'start': 32.96,
#   'duration': 3.46},
#  {'text': 'compared to 14 out of 100\nin South and West Asia',
#   'start': 36.42,
#   'duration': 2.779},
#  {'text': 'and 36 out of 100\nin Latin America.',
#   'start': 39.2,
#   'duration': 3.08},
#  {'text': 'Even in developed countries,\nthe quality of schooling can differ greatly,',
#   'start': 42.28,
#   'duration': 3.22},
#  {'text': 'whether rich or poor.', 'start': 45.5, 'duration': 1.36},
#  {'text': 'High national wealth then,\nis no guarantee of high equality.',
#   'start': 46.86,
#   'duration': 3.52},
#  {'text': 'The U.K., Germany and the U.S. are among the\nrichest countries in the world, but all three rank poorly',
#   'start': 50.38,
#   'duration': 5.16},
#  {'text': 'on an educational inequality league table\nof 41 of the world’s richest countries.',
#   'start': 55.54,
#   'duration': 4.46},
#  {'text': 'By the middle of secondary school,\neducational inequalities are worse',
#   'start': 60.0,
#   'duration': 3.14},
#  {'text': 'than in other countries with much smaller economies\nsuch as Latvia, Spain and Estonia.',
#   'start': 63.14,
#   'duration': 5.04},
#  {'text': 'However, research has shown that child development\nis linked with income.',
#   'start': 68.18,
#   'duration': 3.9},
#  {'text': 'Unsurprisingly, the U.S. and the U.K.\nhave some of the',
#   'start': 72.08,
#   'duration': 2.8},
#  {'text': 'highest levels of income inequality\namong OECD countries.',
#   'start': 74.88,
#   'duration': 3.82},
#  {'text': 'In the U.K., there has been a significant\nlack of social mobility since 1945.',
#   'start': 78.7,
#   'duration': 4.84},
#  {'text': 'As wealth inequality has remained high,\nthere hasn’t been much change',
#   'start': 83.54,
#   'duration': 3.399},
#  {'text': 'in how well British children\nare doing at school.',
#   'start': 86.94,
#   'duration': 2.7},
#  {'text': 'In a 2019 report by the education coalition\nFair Education Alliance,',
#   'start': 89.64,
#   'duration': 4.42},
#  {'text': 'pupils from disadvantaged backgrounds in the U.K.\nlag their peers by more than 8 months',
#   'start': 94.06,
#   'duration': 4.72},
#  {'text': 'in reading, writing and maths by age 11.',
#   'start': 98.78,
#   'duration': 2.94},
#  {'text': 'Children from persistently disadvantaged backgrounds\nare 22 months behind,',
#   'start': 101.72,
#   'duration': 4.72},
#  {'text': 'by the time they finish their school career. Small progress has been made',
#   'start': 106.44,
#   'duration': 4.38},
#  {'text': 'in helping some children almost beat the odds\nand overcome the barriers that face them',
#   'start': 110.82,
#   'duration': 5.898},
#  {'text': 'but the systemic underlying factors\nof our education system',
#   'start': 116.718,
#   'duration': 3.831},
#  {'text': 'still remain, which mean we’re not ever\nreaching the most persistently disadvantaged.',
#   'start': 120.549,
#   'duration': 5.131},
#  {'text': 'So, what are the contributing factors\nof education inequality among children?',
#   'start': 125.68,
#   'duration': 4.52},
#  {'text': 'According to Unicef, a child’s educational\nprogress is linked to their family background.',
#   'start': 130.2,
#   'duration': 4.8},
#  {'text': 'What kind of jobs the parents have\nor whether the child is a first generation immigrant',
#   'start': 135.0,
#   'duration': 4.08},
#  {'text': 'can affect the likelihood of them\ncontinuing into higher education.',
#   'start': 139.08,
#   'duration': 3.56},
#  {'text': 'Inequality between genders is also apparent from\na young age and tends to grow as children get older.',
#   'start': 142.64,
#   'duration': 5.44},
#  {'text': 'Reading abilities among girls\nare generally better than boys by the age of nine',
#   'start': 148.08,
#   'duration': 3.84},
#  {'text': 'and, in turn, that discrepancy is more likely\nto continue in education beyond secondary school.',
#   'start': 151.92,
#   'duration': 5.4},
#  {'text': 'And finally, which school you go to can have\na significant impact on your academic performance.',
#   'start': 157.32,
#   'duration': 4.88},
#  {'text': 'In many countries, the debate on inequality\nin education is seen',
#   'start': 162.2,
#   'duration': 3.33},
#  {'text': 'through the prism of private schools\nversus state schools.',
#   'start': 165.53,
#   'duration': 3.23},
#  {'text': 'The U.K. is home to some very famous private schools\nlike Eton College and Harrow School, behind me.',
#   'start': 168.76,
#   'duration': 5.46},
#  {'text': 'Of the 55 British prime ministers,\nnearly half were educated at just these two schools,',
#   'start': 174.22,
#   'duration': 5.48},
#  {'text': 'along with prominent actors, writers, scientists\nand royalty from across the world.',
#   'start': 179.7,
#   'duration': 5.0},
#  {'text': 'To compare, the entire state school education in England of a young person starting from nursery',
#   'start': 184.7,
#   'duration': 4.94},
#  {'text': 'costs an average of around $96,000.\nThe annual school fees at Harrow, however,',
#   'start': 189.64,
#   'duration': 5.36},
#  {'text': 'cost around $56,000\nfor just one year of a child’s tuition.',
#   'start': 195.0,
#   'duration': 4.76},
#  {'text': 'But even that is dwarfed by private schools\nin Switzerland',
#   'start': 199.76,
#   'duration': 2.6},
#  {'text': 'such as Le Rosey which costs\nmore than $135,000 per year.',
#   'start': 202.36,
#   'duration': 4.88},
#  {'text': 'Many believe that private education\nis at the root of inequality',
#   'start': 207.24,
#   'duration': 3.5},
#  {'text': 'and reduces the chances for those children\nwho attend state schools.',
#   'start': 210.74,
#   'duration': 3.16},
#  {'text': 'The statistics tell us that educational privilege\nprovides significant advantages and opens many doors.',
#   'start': 213.9,
#   'duration': 5.64},
#  {'text': 'In the U.K., nearly a third of members of parliament,\ntwo-thirds of the country’s top doctors',
#   'start': 219.54,
#   'duration': 4.61},
#  {'text': 'and 74% of judges were privately educated.\nThe exam results also reflect the disparity.',
#   'start': 224.15,
#   'duration': 6.05},
#  {'text': 'In 2019, 45.7% of students\nat private schools in the U.K.',
#   'start': 230.2,
#   'duration': 4.66},
#  {'text': 'got A* or As in their final year exams\ncompared to the national average of 25.5%.',
#   'start': 234.86,
#   'duration': 6.68},
#  {'text': 'But there are some state funded schools\nthat buck that trend.',
#   'start': 241.54,
#   'duration': 3.3},
#  {'text': 'This is Mulberry School for Girls\nin east London.',
#   'start': 244.84,
#   'duration': 2.58},
#  {'text': 'It’s located in one of the most\ndisadvantaged areas in the city,',
#   'start': 247.42,
#   'duration': 3.76},
#  {'text': 'yet the exam performance of students here\nis well above national average.',
#   'start': 251.18,
#   'duration': 4.6},
#  {'text': 'Vanessa Ogden is the headteacher here,\nand for the last 15 years,',
#   'start': 255.78,
#   'duration': 3.4},
#  {'text': 'has been instrumental in seeing\nmany of her pupils overturn the odds.',
#   'start': 259.18,
#   'duration': 3.88},
#  {'text': 'As a headteacher, how do you, in your role,\nhelp to tackle education inequality?',
#   'start': 263.06,
#   'duration': 5.8},
#  {'text': 'The first really important way is to have students\nleave with a really great set of qualifications',
#   'start': 268.86,
#   'duration': 6.5},
#  {'text': 'and really great destinations\nto either university or apprenticeships',
#   'start': 275.36,
#   'duration': 4.38},
#  {'text': 'and so that’s the driving force,\nbut of course,',
#   'start': 279.74,
#   'duration': 2.56},
#  {'text': 'inequality brings with it\nmany structural difficulties in your life.',
#   'start': 282.3,
#   'duration': 4.9},
#  {'text': 'But while the pupils at Mulberry School\nhave outperformed their peers for many years,',
#   'start': 287.2,
#   'duration': 3.66},
#  {'text': 'the Covid-19 pandemic may have\nundone much of that work.',
#   'start': 290.86,
#   'duration': 3.54},
#  {'text': 'We know from the research that Covid-19\nhas disproportionately affected',
#   'start': 294.4,
#   'duration': 5.84},
#  {'text': 'people of Black, Asian and minority ethnic background\nand those are the families mainly that we serve',
#   'start': 300.24,
#   'duration': 6.7},
#  {'text': 'and so not only has there been real difficulty\naround finance and resources,',
#   'start': 306.94,
#   'duration': 5.48},
#  {'text': 'but also real difficulty around health.\nThe very first thing that reared its head',
#   'start': 312.42,
#   'duration': 4.3},
#  {'text': 'was period poverty, female students\nnot being able to get sanitary products.',
#   'start': 316.72,
#   'duration': 3.96},
#  {'text': 'We hadn’t realized that really in a way\nschools are the providers of some of those things.',
#   'start': 320.68,
#   'duration': 4.26},
#  {'text': 'Stationery as well.\nSo if you don’t have money or if the shops are shut',
#   'start': 324.94,
#   'duration': 4.03},
#  {'text': 'and you don’t have stationery in the home.',
#   'start': 328.97,
#   'duration': 1.45},
#  {'text': 'And we lent out all the devices that we could,\nso that they could learn at home.',
#   'start': 330.42,
#   'duration': 5.65},
#  {'text': 'In terms of the reasons why Covid-19\nhas exacerbated the disadvantage gap,',
#   'start': 336.07,
#   'duration': 4.89},
#  {'text': 'one big reason is the digital divide,\nbut it’s also a resource divide in general.',
#   'start': 340.96,
#   'duration': 5.52},
#  {'text': 'So some families might not have access\nto laptops to access online learning.',
#   'start': 346.48,
#   'duration': 4.45},
#  {'text': 'They might not have a lot of space.\nThe little progress we have made over the last ten years',
#   'start': 350.93,
#   'duration': 5.03},
#  {'text': 'is likely to have been reversed by lockdown.\nSo what was already a dire situation',
#   'start': 355.96,
#   'duration': 4.91},
#  {'text': 'has been turned into quite a crisis.',
#   'start': 360.87,
#   'duration': 2.31},
#  {'text': 'The pandemic also highlighted another aspect\nof education inequality: private tuition.',
#   'start': 363.18,
#   'duration': 5.16},
#  {'text': 'By mid-April, there were nationwide school closures\nin more than 190 countries,',
#   'start': 368.34,
#   'duration': 4.77},
#  {'text': 'affecting more than 1.5 billion learners.',
#   'start': 373.11,
#   'duration': 2.39},
#  {'text': 'This led to an unprecedented demand\nfor online teaching.',
#   'start': 375.5,
#   'duration': 3.02},
#  {'text': 'Some online tutoring platforms saw the number\nof daily users increase by 1,125% in two weeks.',
#   'start': 378.52,
#   'duration': 7.24},
#  {'text': 'In Singapore, there have even been\ncalls to ban the private tuition industry',
#   'start': 385.76,
#   'duration': 3.62},
#  {'text': 'in an attempt to close the achievement gap.',
#   'start': 389.38,
#   'duration': 2.18},
#  {'text': 'The Covid-19 pandemic also impacted students\nin the U.K. progressing to university.',
#   'start': 391.56,
#   'duration': 5.02},
#  {'text': 'Due to exams being canceled during the lockdown,\nresults were given based on an algorithm,',
#   'start': 396.58,
#   'duration': 4.04},
#  {'text': 'that critics claimed dragged dow\nhigh-achieving pupils in low-achieving schools,',
#   'start': 400.62,
#   'duration': 4.18},
#  {'text': 'compounding the inequalities they face.',
#   'start': 404.8,
#   'duration': 2.46},
#  {'text': 'The Department of Education and the exam boards\ninitially responded by claiming there was no bias,',
#   'start': 407.26,
#   'duration': 4.58},
#  {'text': 'whether on the grounds of deprivation,\ngender or ethnicity.',
#   'start': 411.84,
#   'duration': 3.16},
#  {'text': 'However, they eventually reversed their decision, with\ngrades instead estimated by the students’teachers.',
#   'start': 415.0,
#   'duration': 5.2},
#  {'text': 'So, what can be done to reduce educational inequalities\nboth here and around the world?',
#   'start': 420.2,
#   'duration': 5.14},
#  {'text': 'A former Singaporean education minister\nsaid in 2018 that there should be',
#   'start': 425.34,
#   'duration': 3.95},
#  {'text': 'a broader definition of merit\nto recognize a wider range of skills.',
#   'start': 429.29,
#   'duration': 4.15},
#  {'text': 'We should double up on meritocracy,\nbroaden its definition',
#   'start': 433.44,
#   'duration': 4.57},
#  {'text': 'to embrace various talents and skills.\nWe should not cap achievement at the top,',
#   'start': 438.01,
#   'duration': 5.25},
#  {'text': 'but try harder, work harder,\nto lift the bottom.',
#   'start': 443.26,
#   'duration': 3.6},
#  {'text': 'The Fair Education Alliance also believes\nthere is too much reliance on exams',
#   'start': 446.86,
#   'duration': 3.9},
#  {'text': 'and that education should be more holistic\nto include building aptitude and values.',
#   'start': 450.76,
#   'duration': 5.04},
#  {'text': 'We want an education system\nwhich develops skills',
#   'start': 455.8,
#   'duration': 2.78},
#  {'text': 'and social and emotional competencies\nalongside academic attainment,',
#   'start': 458.58,
#   'duration': 3.28},
#  {'text': 'we want teachers and leaders to be rewarded\nfor serving the most disadvantaged students,',
#   'start': 461.86,
#   'duration': 5.9},
#  {'text': 'we want to engage parents and communities\nfrom all backgrounds in the education system',
#   'start': 467.76,
#   'duration': 5.28},
#  {'text': 'and we want to prepare young people\nfor what comes after school.',
#   'start': 473.04,
#   'duration': 3.28},
#  {'text': 'Education is a way out of difficult situations.\nIt’s also a means of moving yourself up the tree',
#   'start': 476.32,
#   'duration': 9.159},
#  {'text': 'in terms of prosperity,\nand not just financial prosperity',
#   'start': 485.479,
#   'duration': 4.281},
#  {'text': 'but also your kind of spiritual\nand cultural prosperity as well.',
#   'start': 489.76,
#   'duration': 5.379},
#  {'text': 'It’s also the case that a policy that works\nin one country or region may not work in another.',
#   'start': 495.14,
#   'duration': 4.96},
#  {'text': 'Economic inequality, however, is likely to grow\ndue to the Covid 19 pandemic.',
#   'start': 500.1,
#   'duration': 4.52},
#  {'text': 'This means that creating better education systems\nis increasingly important',
#   'start': 504.62,
#   'duration': 4.1},
#  {'text': 'so that a child’s starting point in life\ndoesn’t determine their future.',
#   'start': 508.72,
#   'duration': 3.88},
#  {'text': 'You have to be an optimist,', 'start': 512.6, 'duration': 1.54},
#  {'text': 'otherwise you’d pack up and go home in education,\nyou know, you have to believe there is hope.',
#   'start': 514.14,
#   'duration': 4.5},
#  {'text': 'Hi guys.\nThanks for watching our video.',
#   'start': 519.12,
#   'duration': 1.76},
#  {'text': 'I’d like to know how your schooling\nhas affected your future.',
#   'start': 520.88,
#   'duration': 3.22},
#  {'text': 'What are the education systems like\nin the country you live in?',
#   'start': 524.1,
#   'duration': 3.1},
#  {'text': 'Comment below the video to let us know,\nand remember, subscribe.',
#   'start': 527.2,
#   'duration': 2.92}]

# %%
doc = ""
for line in transcript:
    doc =doc+ ' ' + line['text']
print(type(doc))
print(doc)
#print(len(result))
# Out:
# <class 'str'>
#  Malcolm X once said that
# “Education is the passport to the future.” But what if some passports
# are better than others, giving the holder access
# to better schools and teachers and, in turn,
# a more prosperous future? These inequalities have been around
# long before Covid-19, and yet, the pandemic has both exacerbated them
# and made them more visible. While the standard of education
# varies greatly globally, education inequality happens
# at the local level in all countries. For example, only four
# out of every 100 children in Africa is expected to enter a graduate
# and postgraduate institution, compared to 14 out of 100
# in South and West Asia and 36 out of 100
# in Latin America. Even in developed countries,
# the quality of schooling can differ greatly, whether rich or poor. High national wealth then,
# is no guarantee of high equality. The U.K., Germany and the U.S. are among the
# richest countries in the world, but all three rank poorly on an educational inequality league table
# of 41 of the world’s richest countries. By the middle of secondary school,
# educational inequalities are worse than in other countries with much smaller economies
# such as Latvia, Spain and Estonia. However, research has shown that child development
# is linked with income. Unsurprisingly, the U.S. and the U.K.
# have some of the highest levels of income inequality
# among OECD countries. In the U.K., there has been a significant
# lack of social mobility since 1945. As wealth inequality has remained high,
# there hasn’t been much change in how well British children
# are doing at school. In a 2019 report by the education coalition
# Fair Education Alliance, pupils from disadvantaged backgrounds in the U.K.
# lag their peers by more than 8 months in reading, writing and maths by age 11. Children from persistently disadvantaged backgrounds
# are 22 months behind, by the time they finish their school career. Small progress has been made in helping some children almost beat the odds
# and overcome the barriers that face them but the systemic underlying factors
# of our education system still remain, which mean we’re not ever
# reaching the most persistently disadvantaged. So, what are the contributing factors
# of education inequality among children? According to Unicef, a child’s educational
# progress is linked to their family background. What kind of jobs the parents have
# or whether the child is a first generation immigrant can affect the likelihood of them
# continuing into higher education. Inequality between genders is also apparent from
# a young age and tends to grow as children get older. Reading abilities among girls
# are generally better than boys by the age of nine and, in turn, that discrepancy is more likely
# to continue in education beyond secondary school. And finally, which school you go to can have
# a significant impact on your academic performance. In many countries, the debate on inequality
# in education is seen through the prism of private schools
# versus state schools. The U.K. is home to some very famous private schools
# like Eton College and Harrow School, behind me. Of the 55 British prime ministers,
# nearly half were educated at just these two schools, along with prominent actors, writers, scientists
# and royalty from across the world. To compare, the entire state school education in England of a young person starting from nursery costs an average of around $96,000.
# The annual school fees at Harrow, however, cost around $56,000
# for just one year of a child’s tuition. But even that is dwarfed by private schools
# in Switzerland such as Le Rosey which costs
# more than $135,000 per year. Many believe that private education
# is at the root of inequality and reduces the chances for those children
# who attend state schools. The statistics tell us that educational privilege
# provides significant advantages and opens many doors. In the U.K., nearly a third of members of parliament,
# two-thirds of the country’s top doctors and 74% of judges were privately educated.
# The exam results also reflect the disparity. In 2019, 45.7% of students
# at private schools in the U.K. got A* or As in their final year exams
# compared to the national average of 25.5%. But there are some state funded schools
# that buck that trend. This is Mulberry School for Girls
# in east London. It’s located in one of the most
# disadvantaged areas in the city, yet the exam performance of students here
# is well above national average. Vanessa Ogden is the headteacher here,
# and for the last 15 years, has been instrumental in seeing
# many of her pupils overturn the odds. As a headteacher, how do you, in your role,
# help to tackle education inequality? The first really important way is to have students
# leave with a really great set of qualifications and really great destinations
# to either university or apprenticeships and so that’s the driving force,
# but of course, inequality brings with it
# many structural difficulties in your life. But while the pupils at Mulberry School
# have outperformed their peers for many years, the Covid-19 pandemic may have
# undone much of that work. We know from the research that Covid-19
# has disproportionately affected people of Black, Asian and minority ethnic background
# and those are the families mainly that we serve and so not only has there been real difficulty
# around finance and resources, but also real difficulty around health.
# The very first thing that reared its head was period poverty, female students
# not being able to get sanitary products. We hadn’t realized that really in a way
# schools are the providers of some of those things. Stationery as well.
# So if you don’t have money or if the shops are shut and you don’t have stationery in the home. And we lent out all the devices that we could,
# so that they could learn at home. In terms of the reasons why Covid-19
# has exacerbated the disadvantage gap, one big reason is the digital divide,
# but it’s also a resource divide in general. So some families might not have access
# to laptops to access online learning. They might not have a lot of space.
# The little progress we have made over the last ten years is likely to have been reversed by lockdown.
# So what was already a dire situation has been turned into quite a crisis. The pandemic also highlighted another aspect
# of education inequality: private tuition. By mid-April, there were nationwide school closures
# in more than 190 countries, affecting more than 1.5 billion learners. This led to an unprecedented demand
# for online teaching. Some online tutoring platforms saw the number
# of daily users increase by 1,125% in two weeks. In Singapore, there have even been
# calls to ban the private tuition industry in an attempt to close the achievement gap. The Covid-19 pandemic also impacted students
# in the U.K. progressing to university. Due to exams being canceled during the lockdown,
# results were given based on an algorithm, that critics claimed dragged dow
# high-achieving pupils in low-achieving schools, compounding the inequalities they face. The Department of Education and the exam boards
# initially responded by claiming there was no bias, whether on the grounds of deprivation,
# gender or ethnicity. However, they eventually reversed their decision, with
# grades instead estimated by the students’teachers. So, what can be done to reduce educational inequalities
# both here and around the world? A former Singaporean education minister
# said in 2018 that there should be a broader definition of merit
# to recognize a wider range of skills. We should double up on meritocracy,
# broaden its definition to embrace various talents and skills.
# We should not cap achievement at the top, but try harder, work harder,
# to lift the bottom. The Fair Education Alliance also believes
# there is too much reliance on exams and that education should be more holistic
# to include building aptitude and values. We want an education system
# which develops skills and social and emotional competencies
# alongside academic attainment, we want teachers and leaders to be rewarded
# for serving the most disadvantaged students, we want to engage parents and communities
# from all backgrounds in the education system and we want to prepare young people
# for what comes after school. Education is a way out of difficult situations.
# It’s also a means of moving yourself up the tree in terms of prosperity,
# and not just financial prosperity but also your kind of spiritual
# and cultural prosperity as well. It’s also the case that a policy that works
# in one country or region may not work in another. Economic inequality, however, is likely to grow
# due to the Covid 19 pandemic. This means that creating better education systems
# is increasingly important so that a child’s starting point in life
# doesn’t determine their future. You have to be an optimist, otherwise you’d pack up and go home in education,
# you know, you have to believe there is hope. Hi guys.
# Thanks for watching our video. I’d like to know how your schooling
# has affected your future. What are the education systems like
# in the country you live in? Comment below the video to let us know,
# and remember, subscribe.

# %%
doc=[]
for line in transcript:
  if "\n" in line['text']:
    x=line['text'].replace("\n"," ")
    doc.append(x)
  else:
    doc.append(line['text'])
print(doc)
# Out:
# ['Malcolm X once said that “Education is the passport to the future.”', 'But what if some passports are better than others,', 'giving the holder access to better schools and teachers', 'and, in turn, a more prosperous future?', 'These inequalities have been around long before Covid-19,', 'and yet, the pandemic has both exacerbated them and made them more visible.', 'While the standard of education varies greatly globally,', 'education inequality happens at the local level in all countries.', 'For example, only four out of every 100 children in Africa', 'is expected to enter a graduate and postgraduate institution,', 'compared to 14 out of 100 in South and West Asia', 'and 36 out of 100 in Latin America.', 'Even in developed countries, the quality of schooling can differ greatly,', 'whether rich or poor.', 'High national wealth then, is no guarantee of high equality.', 'The U.K., Germany and the U.S. are among the richest countries in the world, but all three rank poorly', 'on an educational inequality league table of 41 of the world’s richest countries.', 'By the middle of secondary school, educational inequalities are worse', 'than in other countries with much smaller economies such as Latvia, Spain and Estonia.', 'However, research has shown that child development is linked with income.', 'Unsurprisingly, the U.S. and the U.K. have some of the', 'highest levels of income inequality among OECD countries.', 'In the U.K., there has been a significant lack of social mobility since 1945.', 'As wealth inequality has remained high, there hasn’t been much change', 'in how well British children are doing at school.', 'In a 2019 report by the education coalition Fair Education Alliance,', 'pupils from disadvantaged backgrounds in the U.K. lag their peers by more than 8 months', 'in reading, writing and maths by age 11.', 'Children from persistently disadvantaged backgrounds are 22 months behind,', 'by the time they finish their school career. Small progress has been made', 'in helping some children almost beat the odds and overcome the barriers that face them', 'but the systemic underlying factors of our education system', 'still remain, which mean we’re not ever reaching the most persistently disadvantaged.', 'So, what are the contributing factors of education inequality among children?', 'According to Unicef, a child’s educational progress is linked to their family background.', 'What kind of jobs the parents have or whether the child is a first generation immigrant', 'can affect the likelihood of them continuing into higher education.', 'Inequality between genders is also apparent from a young age and tends to grow as children get older.', 'Reading abilities among girls are generally better than boys by the age of nine', 'and, in turn, that discrepancy is more likely to continue in education beyond secondary school.', 'And finally, which school you go to can have a significant impact on your academic performance.', 'In many countries, the debate on inequality in education is seen', 'through the prism of private schools versus state schools.', 'The U.K. is home to some very famous private schools like Eton College and Harrow School, behind me.', 'Of the 55 British prime ministers, nearly half were educated at just these two schools,', 'along with prominent actors, writers, scientists and royalty from across the world.', 'To compare, the entire state school education in England of a young person starting from nursery', 'costs an average of around $96,000. The annual school fees at Harrow, however,', 'cost around $56,000 for just one year of a child’s tuition.', 'But even that is dwarfed by private schools in Switzerland', 'such as Le Rosey which costs more than $135,000 per year.', 'Many believe that private education is at the root of inequality', 'and reduces the chances for those children who attend state schools.', 'The statistics tell us that educational privilege provides significant advantages and opens many doors.', 'In the U ...

# %%
paragraph=" ".join(doc)
print(paragraph)
# Out:
#   M a l c o l m   X   o n c e   s a i d   t h a t
#  “ E d u c a t i o n   i s   t h e   p a s s p o r t   t o   t h e   f u t u r e . ”   B u t   w h a t   i f   s o m e   p a s s p o r t s
#  a r e   b e t t e r   t h a n   o t h e r s ,   g i v i n g   t h e   h o l d e r   a c c e s s
#  t o   b e t t e r   s c h o o l s   a n d   t e a c h e r s   a n d ,   i n   t u r n ,
#  a   m o r e   p r o s p e r o u s   f u t u r e ?   T h e s e   i n e q u a l i t i e s   h a v e   b e e n   a r o u n d
#  l o n g   b e f o r e   C o v i d - 1 9 ,   a n d   y e t ,   t h e   p a n d e m i c   h a s   b o t h   e x a c e r b a t e d   t h e m
